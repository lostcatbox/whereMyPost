# %%
from bs4 import BeautifulSoup
import time
import requests
import json

import requests

s = requests.Session()

req = s.get('https://www.logistics.dhl/kr-ko/home/tracking.html')
print(req)

headers = {
    'Connection': 'keep-alive',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.87 Safari/537.36',
    'Sec-Fetch-Dest': 'empty',
    'Accept': '*/*',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Referer': 'https://www.logistics.dhl/global-en/home/tracking/tracking-express.html?tracking-id=7694274276',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
}

params = (
    ('AWB', '7694274276'),
    ('countryCode', 'g0'),
    ('languageCode', 'en'),
)

html = s.get('https://www.logistics.dhl/utapi', headers=headers, params=params)
print(html)
s.cookies.clear()
raw = html.json()
detail = raw["shipments"][0]
print(raw)

# %%
import requests

cookies = {
    'check': 'true',
    'AMCVS_9D88879D5579828F7F000101%40AdobeOrg': '1',
    's_cc': 'true',
    'bm_mi': '83763740353974F0AF20F4543CC06523~',
    'AMCV_9D88879D5579828F7F000101%40AdobeOrg': '-1712354808%7CMCIDTS%7C18302%7CMCMID%7C21622012726086254240504183797069512295%7CMCAAMLH-1581865007%7C11%7CMCAAMB-1581865007%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1581267407s%7CNONE%7CvVersion%7C4.3.0%7CMCCIDH%7C-896142378',
    'ak_bmsc': '4CA4AD6801D59D824009A29786969B97DC5AC6DA1C630000A31D405EE09EA244~',
    'tracking-id': '7694274276',
    'country': 'kr',
    's_sq': '%5B%5BB%5D%5D',
    'TS01044133': '01914b743db703173de4caf418cfa331d65c22b4c0979d45c46cd0f9ecde2d628aa480e57fdb974115f54c21db60098fbcc1b5b410',
    'mbox': 'session#c431b8a4f8bd4110b807e128bbad6e84#1581264211|PC#c431b8a4f8bd4110b807e128bbad6e84.32_0#1644504997',
    'RT': 'sl=12&ss=1581260195153&tt=13781&obo=0&bcn=%2F%2F684fc53d.akstat.io%2F&sh=1581262350929%3D12%3A0%3A13781%2C1581262328892%3D11%3A0%3A13015%2C1581262307545%3D10%3A0%3A11292%2C1581262305230%3D9%3A0%3A10570%2C1581262296360%3D8%3A0%3A9242&dm=www.logistics.dhl&si=64a0371b-baca-4913-bd30-a295c917c9f4&rl=1&ld=1581262350929&r=https%3A%2F%2Fwww.logistics.dhl%2Fkr-ko%2Fhome%2Ftracking%2Ftracking-express.html%3F451418b8a7f3fad49381c733edf9a2fb&ul=1581262355913&hd=1581262355917',
    'bm_sv': '2CDA0F4D67EA6C4BA0BD3D00C465E740~zyp8FhZgkNwAK8LIEuMECI4SgXs9I0rJTHaz8yxA68r6NfEUXQ41yH0WYq2MT9Of7r/D6kXrWsKsQ7iz24J90dhi3NstX7ZyBWls2sYyb8Y5aYJNRr+IMC8UdsyrcP3weJcOJSFg47NnSIzJhuy1jLtTs8dGSSzD5TomPfdHvaY=',
}

headers = {
    'Connection': 'keep-alive',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.87 Safari/537.36',
    'Sec-Fetch-Dest': 'empty',
    'Accept': '*/*',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Referer': 'https://www.logistics.dhl/kr-ko/home/tracking/tracking-express.html?submit=1&tracking-id=7694274276',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
}

params = (
    ('trackingNumber', '7694274276'),
    ('language', 'ko'),
    ('requesterCountryCode', 'KR'),
)

response = requests.get('https://www.logistics.dhl/utapi', headers=headers, params=params, cookies=cookies)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://www.logistics.dhl/utapi?trackingNumber=7694274276&language=ko&requesterCountryCode=KR', headers=headers, cookies=cookies)
print(response)
# Out:
# <Response [200]>

# %%
raw = response.json()
detail = raw["parcelDetailResultMap"]["resultList"]

post_infor= detail[0]["crgNm"]
post_arrived_time=detail[0]["dTime"]
post_place=detail[0]["regBranNm"]
post_status= detail[0]["scanNm"]

print(post_infor)
print(post_arrived_time)
print(post_place)
print(post_status)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-36-bd17acab7e13> in <module>
# ----> 1 raw = response.json()
#       2 detail = raw["parcelDetailResultMap"]["resultList"]
#       3
#       4 post_infor= detail[0]["crgNm"]
#       5 post_arrived_time=detail[0]["dTime"]
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
# ...

# %%
----------------
# Out:
#   File "<ipython-input-37-0128abb360e6>", line 1
#     ----------------
#                     ^
# SyntaxError: invalid syntax

# %%
\\
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-38-2b72f668c95d> in <module>
#      33                              cookies=cookies,
#      34                              data=data)
# ---> 35 raw = html.json()
#      36 detail = raw["parcelDetailResultMap"]["resultList"]
#      37
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
# ...

# %%
from bs4 import BeautifulSoup
import requests



s = requests.Session()
req = s.get('https://service.epost.go.kr/trace.RetrieveDomRigiTraceList.comm')


data = {
    'sid1': '1415705137861',
}

req = s.post('https://service.epost.go.kr/trace.RetrieveDomRigiTraceList.comm',
                     data=data)
html = req.text
soup = BeautifulSoup(html, 'html.parser')
s.cookies.clear()
post_detail = soup.select('#print > div.h4_wrap.ma_t_5 > table > tbody > tr > td')

post_list = []


for x in post_detail:
    post_list.append(x.text.replace("\t","").replace("/n", "").replace("\n", "").replace("\xa0","").replace(" ",""))


post_all_detail = post_list[-4:]

print(post_all_detail)
# Out:
# ['2020.01.16', '09:23', '수원우체국', '배달완료(배달)(수령인:김*배님-부모)']

# %%
s = requests.Session()
req = s.get('https://www.lotteglogis.com/home/reservation/tracking/')

data = {
    'InvNo': "233548940306",
}

req = s.post('https://www.lotteglogis.com/home/reservation/tracking/linkView/',
             data=data)
html = req.text
soup = BeautifulSoup(html, 'html.parser')
post_detail = soup.select('#contents > div > div.contArea > table > tbody > tr > td')

post_list = []

for x in post_detail:
    post_list.append(
                 x.text.replace("\r", "").replace("\t", "").replace("\n", "").replace("\xa0", "").replace(" ", ""))
post_all_detail = post_list[-4:]

print(post_all_detail)
# Out:
# ['배달완료', '2020-01-14--:--', '고객', '물품을받으셨습니다.']

# %%
s = requests.Session()
req = s.get('https://www.hanjin.co.kr/Delivery_html/')

data = {
    'sel_wbl_num1': '0',
    'wbl_num': '507696243040'
}
params = (
    ('wbl_num', '507696243040'),
)

req = s.post('https://www.hanjin.co.kr/Delivery_html/inquiry/result_waybill.jsp', params=params, data=data)
html = req.text
soup = BeautifulSoup(html, 'html.parser')
s.cookies.clear()
post_detail = soup.select('#result_waybill2 > table > tbody > tr > td')

post_list = []

for x in post_detail:
        post_list.append(
            x.text.replace("\r", "").replace("\t", "").replace("\n", "").replace("\xa0", "").replace(" ", ""))
        
post_all_detail = post_list[-4:]



print(post_all_detail)
# Out:
# ['15:19', '동두천(대)', '배송완료되었습니다.(배송사원:김동영010-9501-6904)', '수령인:석미*(기타)']

# %%
s = requests.Session()
req = s.get('https://www.ilogen.com/web/personal/tkSearch')
post_number= '/' + '95638397046'

req = s.get('https://www.ilogen.com/m/personal/trace'+post_number)
html = req.text
soup = BeautifulSoup(html, 'html.parser')
s.cookies.clear()
post_detail = soup.select('tbody > tr> td')

post_list = []

for x in post_detail:
    post_list.append(
        x.text.replace("\r", "").replace("\t", "").replace("\n", "").replace(" ", ""))

post_all_detail = post_list[-6:]

print(post_all_detail)

# %%
s = requests.Session()
headers = {
    'Connection': 'keep-alive',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Sec-Fetch-User': '?1',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'navigate',
    'Referer': 'https://www.logistics.dhl/kr-ko/home/tracking.html',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
}

req = s.get('https://www.logistics.dhl/kr-ko/home/tracking.html', headers=headers)

params = (
    ('submit', '1'),
    ('tracking-id', 'GM295322752002026135'),
)


req = s.get('https://www.logistics.dhl/kr-ko/home/tracking/tracking-ecommerce.html', params=params, headers=headers)
print(req)
html = req.text
print(html)
soup = BeautifulSoup(html, 'html.parser')

s.cookies.clear()
post_detail = soup.select('body > div.main.facelift.tracking-progress > div.main_area > div.content_main_container > div.content_main_index > div.container > div > div.section.shipmenttracking.tracking.dhl_classes_comp_tracking_params > div.tracking-results.dhl_classes_comp_tracking_results > div.tracking-result.express > table.result-checkpoints.show.result-has-pieces > tbody > tr')
print(post_detail)
# Out:
# <Response [200]>
#
# <!DOCTYPE html>
# <html lang="ko-KR">
#
# 	<head>
# 	<meta charset="utf-8"/>
# 	<title>eCommerce 추적 및 조회 | DHL | Korea, Republic of 한국(대한민국)</title>
#
# 	<link rel="preload" href="/etc/clientlibs/dhl/clientlib-all/css/bundle.f70ebfa4e14db30ba6984382c350ce26.css" as="style" crossorigin/>
# <link rel="preload" href="/etc/clientlibs/dhl/clientlib-all/assets/fonts/4894f07cccaa76e4bea3646b6b85d850.woff" as="font" crossorigin/>
# <link rel="preload" href="/etc/clientlibs/dhl/clientlib-all/assets/fonts/80ba4580b7ed2c8c86fa61f8ca9769d0.woff" as="font" crossorigin/>
# <link rel="preload" href="/etc/clientlibs/dhl/clientlib-all/assets/fonts/85a776b7ab49b62f4b4681606c3d70b2.woff" as="font" crossorigin/>
# <link rel="preload" href="/etc/clientlibs/dhl/clientlib-all/assets/fonts/e7e44fa21225aa3a4621c94ad6e4f9ae.woff" as="font" crossorigin/>
# ...

# %%
import requests

cookies = {
    'cookieDisclaimer': 'seen',
    'check': 'true',
    'AMCVS_9D88879D5579828F7F000101%40AdobeOrg': '1',
    's_cc': 'true',
    'lang': 'en',
    'AMCV_9D88879D5579828F7F000101%40AdobeOrg': '-1712354808%7CMCIDTS%7C18298%7CMCMID%7C21622012726086254240504183797069512295%7CMCAAMLH-1581481948%7C11%7CMCAAMB-1581481948%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1580884348s%7CNONE%7CvVersion%7C4.3.0%7CMCCIDH%7C-896142378',
    'ak_bmsc': '34598B3AF373AF0715CAEA8F7CEAC3133D6F3A33C66000005B453A5EA892F82C~',
    'tracking-id': '7694274276',
    'mbox': 'PC#f0a27b56feb04242bd3306000ec7b041.32_0#1643801836|session#943630dfb773400d8609f10ed0d8a3bc#1580879064',
    's_sq': '%5B%5BB%5D%5D',
    'TS01044133': '01914b743d65b2f87da0db8c247f7f5d095122b84462d6e0a4c37af2070e155e612eb61a0b2ba8da35d3301e7942020cc534a8ce91',
    'bm_sv': '2AD6F62CB30304E37195D74C91D99725~H8KH/e29cAOtLqyNexvjCyk7GLDazQKEudzYQiBAC9kWBKZnEsl4pRB7+QOktCFNzqmacsDcbysLhih3QklRuN9LrXwfvAApWUPQm+Cq/hgaKasfKnOILCk1aPU7VFUfzde0xfa9RyCypAl3G+p/q68PcAtR3gjGghgVIEVLuk8=',
    'RT': 'sl=5&ss=1580877146096&tt=7951&obo=0&sh=1580877202933%3D5%3A0%3A7951%2C1580877199331%3D4%3A0%3A7576%2C1580877189711%3D3%3A0%3A5976%2C1580877187206%3D2%3A0%3A5177%2C1580877149283%3D1%3A0%3A3183&dm=www.logistics.dhl&si=hatck0mftw&rl=1&ld=1580877202934&r=https%3A%2F%2Fwww.logistics.dhl%2Fkr-ko%2Fhome%2Ftracking.html&ul=1580877228971',
}

headers = {
    'Connection': 'keep-alive',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Sec-Fetch-User': '?1',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'navigate',
    'Referer': 'https://www.logistics.dhl/kr-ko/home/tracking.html',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
}

params = (
    ('submit', '1'),
    ('tracking-id', 'GM295322752002026135'),
)

response = requests.get('https://www.logistics.dhl/kr-ko/home/tracking/tracking-ecommerce.html', headers=headers, params=params, cookies=cookies)
print(response)

# %%
s = requests.Session()
headers = {
    'Connection': 'keep-alive',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Sec-Fetch-User': '?1',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'navigate',
    'Referer': 'https://www.logistics.dhl/kr-ko/home/tracking.html',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
}

req = s.get('https://www.logistics.dhl/kr-ko/home/tracking.html', headers=headers)
html = req.text
print(html)
soup = BeautifulSoup(html, 'html.parser')

s.cookies.clear()
post_detail = soup.select('body > div.main.facelift.tracking-progress > div.main_area > div.content_main_container > div.content_main_index > div.container > div > div.section.shipmenttracking.tracking.dhl_classes_comp_tracking_params > div.tracking-results.dhl_classes_comp_tracking_results > div.tracking-result.express > table.result-checkpoints.show.result-has-pieces > tbody > tr')
print(post_detail)
# Out:
# <!DOCTYPE html>
# <html lang="ko-KR">
#
# 	<head>
# 	<meta charset="utf-8"/>
# 	<title>추적 | DHL | Korea, Republic of 한국(대한민국)</title>
#
# 	<link rel="preload" href="/etc/clientlibs/dhl/clientlib-all/css/bundle.f70ebfa4e14db30ba6984382c350ce26.css" as="style" crossorigin/>
# <link rel="preload" href="/etc/clientlibs/dhl/clientlib-all/assets/fonts/4894f07cccaa76e4bea3646b6b85d850.woff" as="font" crossorigin/>
# <link rel="preload" href="/etc/clientlibs/dhl/clientlib-all/assets/fonts/80ba4580b7ed2c8c86fa61f8ca9769d0.woff" as="font" crossorigin/>
# <link rel="preload" href="/etc/clientlibs/dhl/clientlib-all/assets/fonts/85a776b7ab49b62f4b4681606c3d70b2.woff" as="font" crossorigin/>
# <link rel="preload" href="/etc/clientlibs/dhl/clientlib-all/assets/fonts/e7e44fa21225aa3a4621c94ad6e4f9ae.woff" as="font" crossorigin/>
# <link rel="preload" href="/etc/clientlibs/dhl/clientlib-all/assets/fonts/f6c87b8840e4ceeb17e83870618ba178.woff" as="font" crossorigin/>
#
#
# ...

# %%
s = requests.Session()
req = s.get('https://www.logistics.dhl/utapi?trackingNumber=GM295322752002026135&language=ko&requesterCountryCode=KR')
print(req.text.json())
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
# ...

# %%
import requests
from bs4 import BeautifulSoup

s = requests.Session()
req = s.get('https://www.cvsnet.co.kr/reservation-inquiry/delivery/index.do')

headers = {
    'Connection': 'keep-alive',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.87 Safari/537.36',
    'Sec-Fetch-Dest': 'document',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-User': '?1',
    'Referer': 'https://www.cvsnet.co.kr/reservation-inquiry/delivery/index.do',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
}

params = (
    ('dlvry_type', 'domestic'),
    ('invoice_no', '363217073274'),
    ('reservedNo', ''),
    ('rtnUrl', '/reservation-inquiry/delivery/index.do?dlvry_type=domestic&invoice_no=&srch_type=01'),
    ('srch_type', '01'),
)




req = s.get('https://www.cvsnet.co.kr/reservation-inquiry/delivery/index.do', headers=headers, params=params)


html = req.text
soup = BeautifulSoup(html, 'html.parser')
s.cookies.clear()
post_detail = soup.select('#div_result > div > div > div.deliveryInfo2 > ul > li')

post_list = []

for x in post_detail:
    post_list.append(
        x.text.replace("\r", "").replace("\t", "").replace("\n", "").replace("\xa0", "").replace(" ", ""))
post_all_detail = post_list[0]

print(post_all_detail)
# Out:
# 2019-12-3011:36:54강원원주문막제일배달완료하였습니다.

# %%
import requests
import json

cookies = {
    'fdx_cbid': '31214489081579504153189970025871',
    'level': 'test',
    'Rbt': 'f0',
    'check': 'true',
    'AMCVS_1E22171B520E93BF0A490D44%40AdobeOrg': '1',
    '_gcl_au': '1.1.1496353538.1579504156',
    'cc_path': 'ca_english',
    '_abck': '25E76C557140EA9CF02E3098B01BAA3F~0~~-1~-1~-1',
    'fdx_locale': 'ko_KR',
    'fdx_redirect': 'ko-kr',
    'Nina-nina-fedex-session': '%7B%22locale%22%3A%22ko_kr%22%2C%22lcstat%22%3Afalse%7D',
    'tracking_locale': 'ko_KR',
    'siteDC': 'edc',
    'bm_sz': 'B8519C54D2B18B7CE0028A0BB1BD0EED~YAAQZpc7F5hik1RvAQAAiYX8EwYp/7713KCkslW9pC9nWvffYsuepnUt6Bsnf5YHI2pf5Ga+tvMuqhsYBi0RY6p2TPa4WXZAqANmKntfj1TLr3QRKiuC4YeZjHEmBRb/feRI+F2mZ99/kSw1DD5Ty75P7urOSa9qqtHCQSpFLBAaQl8UET/7vOspUVnBWQ0=',
    'AMCV_1E22171B520E93BF0A490D44%40AdobeOrg': '1075005958%7CMCIDTS%7C18298%7CMCMID%7C21868991967060958190479628809464246204%7CMCAAMLH-1581488082%7C11%7CMCAAMB-1581488082%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1580890482s%7CNONE%7CMCAID%7CNONE%7CvVersion%7C4.4.1',
    'ak_bmsc': 'C05AA3D510E4994D1CE54F694608D73B173B9766E25C0000515D3A5E217F0424~',
    's_cc': 'true',
    'ADRUM_BTa': 'R:0|g:448b0226-108e-46ba-a478-186c1bec1efd|n:fedex1_b2302943-9419-49fb-b06e-405cc744a61c',
    'ADRUM_BT1': 'R:0|i:12553236|e:326',
    'isMobile': 'f',
    'isTablet': 'f',
    'isWireless': 'f',
    's_sq': 'fedexglbl%252Cfedexapac%3D%2526c.%2526a.%2526activitymap.%2526page%253Dfedex%25252Ftracking%2526link%253D%2525EB%2525B0%2525B0%2525EC%252586%2525A1%252520%2525EC%2525A1%2525B0%2525ED%25259A%25258C%2526region%253Dnumber%2526pageIDType%253D1%2526.activitymap%2526.a%2526.c%2526pid%253Dfedex%25252Ftracking%2526pidt%253D1%2526oid%253D%2525EB%2525B0%2525B0%2525EC%252586%2525A1%252520%2525EC%2525A1%2525B0%2525ED%25259A%25258C%2526oidt%253D3%2526ot%253DSUBMIT',
    'mbox': 'PC#19945b39fd06440fa99de630c0a88f3e.30_0#1582092943|session#3413810b9183497e8be48f08e0e419fd#1580885203',
    's_pers': '%20s_vnum%3D1580914800069%2526vn%253D1%7C1580914800069%3B%20s_nr%3D1580883306596-Repeat%7C1612419306596%3B%20gpv_pageName%3Dfedex%252Ftracking%7C1580885141265%3B%20s_invisit%3Dtrue%7C1580885141274%3B%20s_dfa%3Dfedexglbl%252Cfedexapac%7C1580885142370%3B',
    's_sess': '%20s_visit%3D1%3B%20s_cc%3Dtrue%3B%20s_ppv%3Dfedex%252Ftracking%252C26%252C25%252C977%3B%20SC_LINKS%3D%3B%20setLink%3D%3B',
    'bm_sv': '69FF23286B1D133ACBDBC172D47FDE88~5hI6UUXmIgl2RQm00jzlgEO+7+pzexOjhVmHBrRH26rYO6EH0lBBYWWT7HmHiVXKcyeEchbXMkqi9QSAoUcTxiiKh7OZdoOmJLJlArpI1esHKApzt5bpx2rGe1bEKnGJiE2UDewqPHG3U9D2miWCK4jSfOXY18qactF6lmcfkZE=',
}

headers = {
    'Connection': 'keep-alive',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache',
    'Accept': '*/*',
    'X-Requested-With': 'XMLHttpRequest',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Origin': 'https://www.fedex.com',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Referer': 'https://www.fedex.com/apps/fedextrack/index.html?tracknumbers=110738916651&cntry_code=kr',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
}

data = {
  'data': '{"TrackPackagesRequest":{"appType":"WTRK","appDeviceType":"DESKTOP","supportHTML":true,"supportCurrentLocation":true,"uniqueKey":"","processingParameters":{},"trackingInfoList":[{"trackNumberInfo":{"trackingNumber":"110738916651","trackingQualifier":"","trackingCarrier":""}}]}}',
  'action': 'trackpackages',
  'locale': 'ko_KR',
  'version': '1',
  'format': 'json'
}

r = requests.post('https://www.fedex.com/trackingCal/track', headers=headers, cookies=cookies, data=data)



dic = r.json()

x = json.dumps(dic, ensure_ascii=False)

# %%
import json

dic = r.json()

x = json.dumps(dic, ensure_ascii=False)

detail = x.json()["TrackPackagesResponse"]["packageList"]

# %%
import requests

cookies = {
    'serviceGbn': 'null',
    'PHAROS_VISITOR': '00000000016f80bd7d69786d0ade251b',
    'JSESSIONID': 'kkEgFKlTT8C9I8NGWGtPWwakYUOHbxGcfwwuHmpebTlH3IwF4z2q20hfs6eGN3vj.epost1_servlet_service',
    'ckstm': '1580887288572',
}

headers = {
    'Connection': 'keep-alive',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache',
    'Origin': 'https://service.epost.go.kr',
    'Upgrade-Insecure-Requests': '1',
    'Content-Type': 'application/x-www-form-urlencoded',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Sec-Fetch-User': '?1',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'navigate',
    'Referer': 'https://service.epost.go.kr/trace.RetrieveEmsRigiTrace.comm',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
}

data = {
  'POST_CODE': 'EB709865140CN',
  'displayHeader': ''
}

response = requests.post('https://service.epost.go.kr/trace.RetrieveEmsRigiTraceList.comm', headers=headers, cookies=cookies, data=data)

# %%
s = requests.Session()

headers = {
    'Connection': 'keep-alive',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache',
    'Origin': 'https://service.epost.go.kr',
    'Upgrade-Insecure-Requests': '1',
    'Content-Type': 'application/x-www-form-urlencoded',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Sec-Fetch-User': '?1',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'navigate',
    'Referer': 'https://service.epost.go.kr/trace.RetrieveEmsRigiTrace.comm',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
}

req = s.get('https://service.epost.go.kr/trace.RetrieveEmsRigiTrace.comm', headers=headers)



data = {
  'POST_CODE': 'EB709865140CN',
  'displayHeader': ''
}

req = s.post('https://service.epost.go.kr/trace.RetrieveEmsRigiTraceList.comm', headers=headers, data=data)

html = req.text
soup = BeautifulSoup(html, 'html.parser')


post_detail = soup.select('#print > table.table_col.detail_off.ma_t_5 > tr ')

post_list = []

for x in post_detail:
    post_list.append(x.text.replace("\r", "").replace("\t", "").replace("\n", "").replace("\xa0", ""))

post_all_detail = post_list[-1:]

print(post_all_detail)

# %%
        headers = {
            'Connection': 'keep-alive',
            'Pragma': 'no-cache',
            'Cache-Control': 'no-cache',
            'Upgrade-Insecure-Requests': '1',
            'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
            'Sec-Fetch-User': '?1',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
            'Sec-Fetch-Site': 'none',
            'Sec-Fetch-Mode': 'navigate',
            'Accept-Encoding': 'gzip, deflate, br',
            'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
        }

        s = requests.Session()

        req = s.get('https://www.logistics.dhl/kr-ko/home/tracking.html', headers=headers)
        print(req)






#         params = (
#             ('trackingNumber', post_number),
#             ('language', 'ko'),
#             ('requesterCountryCode', 'KR'),
#         )

#         req = requests.get('https://www.logistics.dhl/utapi', headers=headers, params=params, cookies=cookies)
#         json = req.json()["shipments"][0]
#         service_name = json["service"]
#         timestamp = json["status"]["timestamp"]
#         status = json["status"]["status"]

#         post_all_detail = [service_name, timestamp, status]
#         print(post_all_detail)

# %%
headers = {
'Connection': 'keep-alive',
'Pragma': 'no-cache',
'Cache-Control': 'no-cache',
'Upgrade-Insecure-Requests': '1',
'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
'Sec-Fetch-User': '?1',
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
'Sec-Fetch-Site': 'none',
'Sec-Fetch-Mode': 'navigate',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
}

params = (
('trackingNumber', post_number),
('language', 'ko'),
('requesterCountryCode', 'KR'),
)

req = requests.get('https://www.logistics.dhl/utapi', headers=headers, params=params, cookies=cookies)
json = req.json()["shipments"][0]
service_name = json["service"]
timestamp = json["status"]["timestamp"]
status = json["status"]["status"]

post_all_detail = [service_name, timestamp, status]
print(post_all_detail)

# %%
import requests

cookies = {
    'frm': 'null',
    '_ga': 'GA1.3.942055720.1578031151',
    'NA_SAC': 'dT1odHRwcyUzQSUyRiUyRnd3dy5jdnNuZXQuY28ua3IlMkZyZXNlcnZhdGlvbi1pbnF1aXJ5JTJGZG9tZXN0aWMlMkZhbGwtY29tcGxldGUuZG98cj0=',
    'JSESSIONCVS': '0001HkCb97Rmr8mGyRGmmrQ9oaI:-1',
    '_gid': 'GA1.3.548605996.1581143309',
    '_gat_gtag_UA_117614738_1': '1',
    'wcs_bt': 's_23c05d078f:1581143308',
}

headers = {
    'Connection': 'keep-alive',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.87 Safari/537.36',
    'Sec-Fetch-Dest': 'document',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-User': '?1',
    'Referer': 'https://www.cvsnet.co.kr/reservation-inquiry/delivery/index.do',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
}

params = (
    ('dlvry_type', 'domestic'),
    ('invoice_no', '363217073274'),
    ('reservedNo', ''),
    ('rtnUrl', '/reservation-inquiry/delivery/index.do?dlvry_type=domestic&invoice_no=&srch_type=01'),
    ('srch_type', '01'),
)

response = requests.get('https://www.cvsnet.co.kr/reservation-inquiry/delivery/index.do', headers=headers, params=params, cookies=cookies)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://www.cvsnet.co.kr/reservation-inquiry/delivery/index.do?dlvry_type=domestic&invoice_no=363217073274&reservedNo=&rtnUrl=%2Freservation-inquiry%2Fdelivery%2Findex.do%3Fdlvry_type%3Ddomestic%26invoice_no%3D%26srch_type%3D01&srch_type=01', headers=headers, cookies=cookies)
print(response)
# Out:
# <Response [200]>

# %% [raw]
# import requests
#
# s = requests.Session()
# req = s.get('https://www.cvsnet.co.kr/reservation-inquiry/delivery/index.do')
#
# headers = {
#     'Connection': 'keep-alive',
#     'Pragma': 'no-cache',
#     'Cache-Control': 'no-cache',
#     'Upgrade-Insecure-Requests': '1',
#     'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.87 Safari/537.36',
#     'Sec-Fetch-Dest': 'document',
#     'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
#     'Sec-Fetch-Site': 'same-origin',
#     'Sec-Fetch-Mode': 'navigate',
#     'Sec-Fetch-User': '?1',
#     'Referer': 'https://www.cvsnet.co.kr/reservation-inquiry/delivery/index.do',
#     'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja;q=0.6',
# }
#
# params = (
#     ('dlvry_type', 'domestic'),
#     ('invoice_no', '363217073274'),
#     ('reservedNo', ''),
#     ('rtnUrl', '/reservation-inquiry/delivery/index.do?dlvry_type=domestic&invoice_no=&srch_type=01'),
#     ('srch_type', '01'),
# )
#
#
#
#
# req = s.get('https://www.cvsnet.co.kr/reservation-inquiry/delivery/index.do', headers=headers, params=params)
#
# print(req)
#
# html = req.text
# soup = BeautifulSoup(html, 'html.parser')
# s.cookies.clear()
# post_detail = soup.select('#div_result > div > div > div.deliveryInfo2 > ul > li')
#
# post_list = []
#
# for x in post_detail:
#     post_list.append(
#         x.text)
#
# post_all_detail = post_list
